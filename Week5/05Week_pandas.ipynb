# %% [markdown]
# <a href="https://colab.research.google.com/github/parksuejin1026/2026_BDA_Study/blob/main/Week5/05Week_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # PANDAS

# %% [markdown]
# Series : 하나의 열

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], name = 'first')
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# Name: first, dtype: float64

# %%
s.name # 열이름
# Out:
# 'first'

# %%
s.index # 인덱스 유형
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s.values # 열 값들 배열로 출력
# Out:
# array([ 1.,  3.,  5., nan,  6.,  8.])

# %%
s.shape
# Out:
# (6,)

# %%
s.size
# Out:
# 6

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# Name: first, dtype: float64

# %%
s[1]
# Out:
# np.float64(3.0)

# %%
s[1:5]
# Out:
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# Name: first, dtype: float64

# %%
s.index = list('abcdef') # 리스트로 변환하여 6개의 인덱스 생성
s
# Out:
# a    1.0
# b    3.0
# c    5.0
# d    NaN
# e    6.0
# f    8.0
# Name: first, dtype: float64

# %%
print(s['b'], s['d'])
# Out:
# 3.0 nan

# %%
s['c':'e']
# Out:
# c    5.0
# d    NaN
# e    6.0
# Name: first, dtype: float64

# %%
s['b':'f']
# Out:
# b    3.0
# c    5.0
# d    NaN
# e    6.0
# f    8.0
# Name: first, dtype: float64

# %%
s[0:3]
# Out:
# a    1.0
# b    3.0
# c    5.0
# Name: first, dtype: float64

# %%
s1 = s[1:4]
s1
# Out:
# b    3.0
# c    5.0
# d    NaN
# Name: first, dtype: float64

# %%
s1[0]
# Out:
# /tmp/ipykernel_8069/643609873.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]
# np.float64(3.0)

# %%
s1[0] = 10
s1
# Out:
# /tmp/ipykernel_8069/1715506060.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   s1[0] = 10
# b    10.0
# c     5.0
# d     NaN
# Name: first, dtype: float64

# %%
s
# Out:
# a     1.0
# b    10.0
# c     5.0
# d     NaN
# e     6.0
# f     8.0
# Name: first, dtype: float64

# %%
s.index = np.arange(1, 7)
s
# Out:
# 1     1.0
# 2    10.0
# 3     5.0
# 4     NaN
# 5     6.0
# 6     8.0
# Name: first, dtype: float64

# %%
s[1]
# Out:
# np.float64(1.0)

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8069/243613605.py in <cell line: 0>()
# ----> 1 s[0]
#
# ...

# %%
s[1:3]
# Out:
# 2    10.0
# 3     5.0
# Name: first, dtype: float64

# %%
age = pd.Series([9, 17, 32, 45, 65, 98], index = list('abcdef'), name = 'age')
age
# Out:
# a     9
# b    17
# c    32
# d    45
# e    65
# f    98
# Name: age, dtype: int64

# %%
age['b']
# Out:
# np.int64(17)

# %%
age[[1, 3, 5]]
# Out:
# /tmp/ipykernel_8069/1546391730.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age[[1, 3, 5]]
# b    17
# d    45
# f    98
# Name: age, dtype: int64

# %%
age[['a', 'f', 'd']]
# Out:
# a     9
# f    98
# d    45
# Name: age, dtype: int64

# %%
age[['c']]
# Out:
# c    32
# Name: age, dtype: int64

# %%
s = pd.Series([3, 6, -3, 0, -4, 8, -7])
s
# Out:
# 0    3
# 1    6
# 2   -3
# 3    0
# 4   -4
# 5    8
# 6   -7
# dtype: int64
